# %%
from google import genai
import os
from IPython.display import display, Markdown

# Configure API key (replace with your actual key or use environment variable)
GOOGLE_API_KEY = os.getenv("GEMINI_API_KEY", "YOUR_API_KEY_HERE")

# Initialize the client
client = genai.Client(api_key=GOOGLE_API_KEY)

# Set the model to use
MODEL_ID = "gemini-2.5-flash" 

prompt = """OBJECTIVE: Make legal content accessible to non-technical staff.
TASK: Below is a paragraph from a banking compliance document. You have to rewrite it in plain English suitable for branch staff training. Use very simple words for the non-technical staff to understand very clearly.
Banking Compliance Document:
"As per the bank’s Customer Due Diligence (CDD) Policy, all branches must verify the identity and address of every new customer before opening an account. This includes collecting valid KYC documents, screening the customer against regulatory watchlists, and ensuring that the customer profile is consistent with their stated source of funds. Branch staff must also report any suspicious or unusual customer behavior to the Compliance Department without informing the customer, as per the internal AML reporting guidelines."
CONTEXT: This will be
AUDIENCE: Non-technical staff
"""
response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt
)

# %%
display(Markdown("### Prompt Response:"))
display(Markdown(response.text))
# Out:
# ### Prompt Response:
# Here's the paragraph rewritten in plain English for non-technical branch staff training:
#
# ---
#
# **Understanding Our Customers: What You Need to Do**
#
# Whenever someone new wants to open an account with us, we have important rules to follow to get to know them. This means you **must always check and confirm who they are and where they live before you open their account.**
#
# To do this, you need to:
#
# *   **Collect their ID and address proof:** Get official documents like a driver's license, passport, and a recent utility bill. These help us confirm their identity and address.
# *   **Run quick checks:** We need to quickly check their name against special lists to make sure we're not doing business with anyone we shouldn't be.
# *   **Understand their money:** Make sure what they tell us about where their money comes from makes sense for them and their job.
#
# **What to do if something seems wrong:**
#
# It's also super important that if you ever see anything **suspicious or unusual** about a customer or what they are doing, you **must report it right away**. Tell our special Compliance team immediately.
#
# **Crucially, do NOT tell the customer that you are reporting them.** This helps us follow our rules to stop illegal money activities and keep our bank safe.
