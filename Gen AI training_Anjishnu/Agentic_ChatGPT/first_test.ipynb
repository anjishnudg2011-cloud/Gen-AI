# %%
# %pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2.0.0,>=1.3.2 (from langchain-openai)
#   Downloading langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Downloading openai-2.33.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.3.2->langchain-openai)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.12.1)
# Requirement already satisfied: certifi in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.6.3)
# Requirement already satisfied: colorama in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
# Downloading langchain_core-1.3.2-py3-none-any.whl (542 kB)
#    ---------------------------------------- 0.0/542.4 kB ? eta -:--:--
#    ---------------------------------------- 542.4/542.4 kB 1.7 MB/s  0:00:00
# Downloading openai-2.33.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------------------------ --- 1.0/1.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.7 MB/s  0:00:00
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    ---------------------------------------- 879.1/879.1 kB 4.2 MB/s  0:00:00
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl (277 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, langchain-protocol, jiter, tiktoken, openai, langchain-core, langchain-openai
#
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ----- ---------------------------------- 1/8 [regex]
#    ----- ---------------------------------- 1/8 [regex]
#    ----- ---------------------------------- 1/8 [regex]
#    ---------- ----------------------------- 2/8 [langchain-protocol]
#    -------------------- ------------------- 4/8 [tiktoken]
#    -------------------- ------------------- 4/8 [tiktoken]
#    -------------------- ------------------- 4/8 [tiktoken]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------- -------------- 5/8 [openai]
#   Attempting uninstall: langchain-core
#    ------------------------- -------------- 5/8 [openai]
#     Found existing installation: langchain-core 1.2.23
#    ------------------------- -------------- 5/8 [openai]
#    ------------------------------ --------- 6/8 [langchain-core]
#     Uninstalling langchain-core-1.2.23:
#    ------------------------------ --------- 6/8 [langchain-core]
#       Successfully uninstalled langchain-core-1.2.23
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-core]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ---------------------------------------- 8/8 [langchain-openai]
#
# Successfully installed jiter-0.14.0 langchain-core-1.3.2 langchain-openai-1.2.1 langchain-protocol-0.0.15 openai-2.33.0 regex-2026.4.4 tiktoken-0.12.0 tqdm-4.67.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# Initialize the model
llm = ChatOpenAI(
    api_key="your-openai-api-key-here",  # Replace with your key
    model="gpt-4o"
)

# Send a test message
response = llm.invoke([HumanMessage(content="Say hello in one sentence.")])

print("Response:", response.content)
