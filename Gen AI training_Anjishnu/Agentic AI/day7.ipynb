# %%
# %pip install google-genai google-auth
# Out:
# Requirement already satisfied: google-genai in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.68.0)
# Requirement already satisfied: google-auth in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.49.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth) (46.0.6)
# Requirement already satisfied: idna>=2.8 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: certifi in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cryptography>=38.0.3->google-auth) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install google-genai
#pip install google-auth
 
from google.genai import Client
from google.oauth2.service_account import Credentials
api_key_path = "gen-lang-client-0384449393-2ea7b2fc5197.json"
 
credentials = Credentials.from_service_account_file(
    api_key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"]
)
 
PROJECT_ID =  "gen-lang-client-0384449393"
REGION = "us-central1"
MODEL_NAME = "gemini-2.5-flash"
 
client = Client(
    vertexai=True,
    project=PROJECT_ID,
    location=REGION,
    credentials=credentials
)

# %%
#pip install google-genai
#pip install google-auth
#using gcloud executing program
from google.genai import Client
 
PROJECT_ID =  "gen-lang-client-0384449393"
REGION = "us-central1"
MODEL_NAME = "gemini-2.5-flash"
 
client = Client(
    vertexai=True,
    project=PROJECT_ID,
    location=REGION,
)
 
response = client.models.generate_content(
    model=MODEL_NAME,
    contents="What is the color of Apple"
)
 
print("Model Response:\n", response.text)
# Out:
# Model Response:
#  That's a fun question because "Apple" can mean two very different things!
#
# 1.  **The color of an apple (the fruit):**
#     Apples come in a wide variety of colors! Most famously, they are **red** (like Gala, Fuji, Red Delicious), but many varieties are also **green** (like Granny Smith), **yellow** (like Golden Delicious), or a combination of these colors, sometimes with pink or blush tones (like Pink Lady or Honeycrisp).
#
# 2.  **The color of Apple (the company - Apple Inc.):**
#     Apple's iconic logo is typically depicted in a **monochromatic** style – often **silver, white, black, or gray**. Their brand identity and product design philosophy tend to favor minimalist, sleek aesthetics, often utilizing colors like **silver, space gray, white, and black** for their devices.
#
#     Historically, the original Apple logo from 1977 to 1998 was a **rainbow** apple, but for many years now, it has been monochromatic. While their core brand is monochromatic, their products (especially iPhones, iMacs, and Apple Watches) are available in a wide range of colors that change with different models and generations.
#
# So, the answer depends entirely on whether you mean the fruit or the technology company!

# %%
import os
from google import genai

os.environ["GOOGLE_API_KEY"] = "AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc"
client = genai.Client()
'''
client= genai.Client(
    api_key="AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc",
)
'''
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make predictions.

# %%
print("total output tokens:", response.usage_metadata.total_token_count)
# Out:
# total output tokens: 221

# %%
from google import genai
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc"
client= genai.Client()

prompt = "Explain machine learning"
input_tokens_count=client.models.count_tokens(
    model="gemini-2.5-flash",
    contents=prompt 
)
print("Input tokens:", input_tokens_count)

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt 
)
print("Response:", response.text)   
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) total_tokens=4 cached_content_token_count=None
# Response: Machine Learning (ML) is a subfield of Artificial Intelligence (AI) that empowers computer systems to **learn from data** without being explicitly programmed for every specific task. Instead of a programmer writing strict, step-by-step instructions for every possible scenario, ML models are trained on vast amounts of data, allowing them to identify patterns, make predictions, and adapt their behavior over time.
#
# Think of it like teaching a child:
#
# *   **Traditional Programming:** You give the child a strict rulebook for everything they might encounter. "If you see something red and round with seeds, call it an apple. If you see something yellow and long, call it a banana."
# *   **Machine Learning:** You show the child many pictures of apples (red, green, big, small) and many pictures of bananas. You tell them, "These are apples, and these are bananas." Over time, the child learns to identify new apples and bananas on their own, even if they look a little different from the ones they've seen before, by recognizing the underlying characteristics.
#
# ### The Core Idea: Learning from Data
#
# At its heart, machine learning is about:
#
# 1.  **Data Input:** Feeding a machine learning algorithm a large dataset. This data can be anything: images, text, numbers, sounds, etc.
# 2.  **Pattern Recognition:** The algorithm analyzes this data to discover hidden patterns, relationships, and structures.
# 3.  **Model Creation:** Based on these learned patterns, the algorithm builds a "model." This model is essentially a sophisticated set of rules, parameters, or statistical representations that capture the insights from the training data.
# 4.  **Prediction/Decision Making:** Once trained, the model can then be presented with new, unseen data and use its learned patterns to make predictions, classifications, or decisions.
# 5.  **Iteration & Improvement:** The model's performance can be evaluated, and if it's not accurate enough, more data can be fed to it, or the algorithm can be fine-tuned, allowing it to improve over time.
#
# ### Why is ML So Powerful and Popular Now?
#
# 1.  **Vast Amounts of Data:** We're generating more data than ever before (internet usage, sensors, social media, etc.), which acts as the "fuel" for ML models.
# 2.  **Increased Computational Power:** Modern hardware (especially GPUs) and cloud computing provide the processing power needed to train complex models on massive datasets.
# 3.  **Improved Algorithms:** Breakthroughs in ML research, particularly in areas like deep learning, have led to more sophisticated and effective algorithms.
# 4.  **Accessibility:** Open-source libraries (like TensorFlow, PyTorch, Scikit-learn) have made machine learning tools available to a wider audience.
#
# ### Types of Machine Learning
#
# There are three main categories of machine learning:
#
# 1.  **Supervised Learning:**
#     *   **Concept:** The model learns from "labeled" data, meaning each piece of input data is paired with the correct output. It's like having a teacher provide the answers.
#     *   **Goal:** To predict an output for new, unseen inputs.
#     *   **Examples:**
#         *   **Classification:** Predicting a category (e.g., "spam" or "not spam" email, "dog" or "cat" in an image).
#         *   **Regression:** Predicting a continuous value (e.g., predicting house prices based on features, forecasting stock prices, predicting temperature).
#
# 2.  **Unsupervised Learning:**
#     *   **Concept:** The model learns from "unlabeled" data, meaning there are no predefined output labels. It's like exploring data without specific guidance.
#     *   **Goal:** To discover hidden patterns, structures, or relationships within the data.
#     *   **Examples:**
#         *   **Clustering:** Grouping similar data points together (e.g., segmenting customers into different groups based on their purchasing behavior).
#         *   **Dimensionality Reduction:** Simplifying complex data by reducing the number of variables, while retaining important information.
#
# 3.  **Reinforcement Learning:**
#     *   **Concept:** An "agent" learns to make decisions by interacting with an environment. It receives "rewards" for desirable actions and "penalties" for undesirable ones. It's like training a pet with treats.
#     *   **Goal:** To learn an optimal strategy or "policy" that maximizes cumulative rewards over time.
#     *   **Examples:** Training AI to play games (Go, Chess, video games), robotics (learning to walk or grasp objects), autonomous vehicles.
#
# ### Real-World Applications
#
# Machine learning is everywhere today:
#
# *   **Recommendation Systems:** "Customers who bought this also bought..." (Amazon, Netflix, Spotify).
# *   **Image and Speech Recognition:** Facial recognition in phones, voice assistants (Siri, Alexa, Google Assistant).
# *   **Spam Detection:** Filtering unwanted emails.
# *   **Fraud Detection:** Identifying suspicious financial transactions.
# *   **Medical Diagnosis:** Assisting doctors in detecting diseases from medical images (X-rays, MRIs).
# *   **Natural Language Processing (NLP):** Translation services (Google Translate), sentiment analysis, chatbots.
# *   **Self-Driving Cars:** Perceiving the environment, making driving decisions.
# *   **Personalized Feeds:** Social media algorithms determining what content you see.
#
# ### Challenges and Ethical Considerations
#
# While powerful, ML also comes with challenges:
#
# *   **Data Quality and Bias:** If the training data is biased or poor quality, the model will reflect and even amplify those biases, leading to unfair or incorrect outcomes.
# *   **Interpretability:** Some complex models (especially deep learning) can be "black boxes," making it hard to understand *why* they made a particular decision.
# *   **Privacy:** Training models often requires large amounts of personal data, raising privacy concerns.
# *   **Job Displacement:** Automation powered by ML could impact certain job sectors.
# *   **Misuse:** The potential for misuse in areas like surveillance or autonomous weapons.
#
# In summary, Machine Learning is a transformative technology that allows computers to learn intelligently from data, enabling them to solve complex problems and automate tasks that were once exclusively within the domain of human intelligence.
# Total tokens used: 2430

# %%
print(dir(response.usage_metadata))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__firstlineno__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_check_field_type_mismatches', '_copy_and_set_values', '_from_response', '_get_value', '_iter', '_setattr_handler', 'cache_tokens_details', 'cached_content_token_count', 'candidates_token_count', 'candidates_tokens_details', 'construct', 'copy', 'dict', 'from_orm', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'parse_file', 'parse_obj', 'parse_raw', 'prompt_token_count', 'prompt_tokens_details', 'schema', 'schema_json', 'thoughts_token_count', 'to_json_dict', 'tool_use_prompt_token_count', 'tool_use_prompt_tokens_details', 'total_token_count', 'traffic_type', 'update_forward_refs', 'validate']

# %%
print("Input tokens:", response.usage_metadata.prompt_token_count)
print("Output tokens:", response.usage_metadata.candidates_token_count)
print("Thought token count:", response.usage_metadata.thoughts_token_count)
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: 4
# Output tokens: 1318
# Thought token count: 1108
# Total tokens used: 2430

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc"
client= genai.Client()

prompt = "Explain cloud computing"

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt ,
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0))
)
print("Response:", response.text)
# Out:
# Response: Imagine you're baking a cake. Traditionally, you'd buy all the ingredients, mix them yourself, and bake it in your own oven. This is like **on-premise computing**: you own and manage all the the hardware and software.
#
# Now, imagine you want a cake, but you don't want to do all that work. You have a few options:
#
# 1.  **You go to a bakery and buy a cake.** You get a finished product, but you can't customize it much, and you don't control the ingredients or the oven. This is like **Software as a Service (SaaS)**.
#
#     *   **Examples:** Gmail, Netflix, Salesforce, Dropbox, Microsoft 365.
#     *   **What you manage:** Basically nothing. You just use the software.
#     *   **What the provider manages:** Everything else – the servers, storage, networking, operating systems, applications, data, security, updates.
#
# 2.  **You order a custom cake from a baker.** You tell them exactly what kind of cake you want (flavor, frosting, decorations), but they still use their own kitchen and equipment to make it. You're responsible for the design, but not the baking process itself. This is like **Platform as a Service (PaaS)**.
#
#     *   **Examples:** Google App Engine, Heroku, AWS Elastic Beanstalk, Azure App Service.
#     *   **What you manage:** Your applications and the data they use.
#     *   **What the provider manages:** The underlying infrastructure (servers, storage, networking), operating systems, runtime environments (like Java or Python), middleware, and tools.
#
# 3.  **You rent a fully equipped commercial kitchen.** It has ovens, mixers, fridges – everything you need. You bring your own ingredients and recipes, and you cook the cake yourself. You have a lot of control over the process, but you don't have to buy or maintain the kitchen equipment. This is like **Infrastructure as a Service (IaaS)**.
#
#     *   **Examples:** Amazon Web Services (AWS) EC2, Microsoft Azure Virtual Machines, Google Compute Engine.
#     *   **What you manage:** Your operating systems, applications, data, and potentially middleware.
#     *   **What the provider manages:** The physical infrastructure – servers, storage, networking, and virtualization.
#
# ---
#
# ### So, what is Cloud Computing in a nutshell?
#
# **Cloud computing is the on-demand delivery of computing services—including servers, storage, databases, networking, software, analytics, and intelligence—over the Internet ("the cloud") to offer faster innovation, flexible resources, and economies of scale.**
#
# Instead of owning and maintaining your own computing infrastructure (like your own data center with physical servers), you can access these services from a third-party provider (like Amazon, Google, or Microsoft) whenever you need them, paying only for what you use.
#
# ---
#
# ### Key Characteristics of Cloud Computing:
#
# *   **On-demand self-service:** Users can provision computing resources (like a server) without human interaction from the service provider.
# *   **Broad network access:** Capabilities are available over the network and accessed through standard mechanisms that promote use by heterogeneous thin or thick client platforms (e.g., mobile phones, laptops, workstations).
# *   **Resource pooling:** The provider's computing resources are pooled to serve multiple consumers using a multi-tenant model, with different physical and virtual resources dynamically assigned and reassigned according to consumer demand.
# *   **Rapid elasticity:** Capabilities can be elastically provisioned and released, in some cases automatically, to scale rapidly outward and inward commensurate with demand.
# *   **Measured service:** Cloud systems automatically control and optimize resource use by leveraging a metering capability at some level of abstraction appropriate to the type of service (e.g., storage, processing, bandwidth). You pay only for what you use.
#
# ---
#
# ### Why is Cloud Computing popular? (The Benefits)
#
# *   **Cost Savings:** No need to buy expensive hardware or maintain your own data centers. You pay only for what you use.
# *   **Scalability:** Easily increase or decrease resources (like computing power or storage) as your needs change, often automatically. You can handle sudden spikes in traffic without downtime.
# *   **Flexibility & Agility:** Quickly deploy new applications and services, experiment with new ideas, and adapt to market changes faster.
# *   **Reliability:** Cloud providers often have redundant systems and backup capabilities, making your data and applications more resilient to outages.
# *   **Global Reach:** Deploy your applications to data centers around the world, bringing your services closer to your users for better performance.
# *   **Security:** Major cloud providers invest heavily in security measures, often exceeding what individual companies can afford.
# *   **Focus on Core Business:** You can offload IT management to experts and focus your own resources on developing your products and services.
#
# ---
#
# In essence, cloud computing is like outsourcing your IT infrastructure and services to a specialist, allowing you to leverage powerful, scalable, and reliable computing resources without the burden of owning and managing them yourself.

# %%
print("Input tokens:", response.usage_metadata.prompt_token_count)
print("Output tokens:", response.usage_metadata.candidates_token_count)
print("Thought token count:", response.usage_metadata.thoughts_token_count)
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: 4
# Output tokens: 1076
# Thought token count: None
# Total tokens used: 1080

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc"
client= genai.Client()

prompt = "Explain cloud computing"

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt ,
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0),max_output_tokens=50 ),
        
)
print("Response:", response.text)
# Out:
# Response: At its simplest, **cloud computing is the delivery of computing services over the internet.**
#
# Instead of keeping data files or software on your own hard drive or a local server in your office, you access them over the web. When

# %%
print("Input tokens:", response.usage_metadata.prompt_token_count)
print("Output tokens:", response.usage_metadata.candidates_token_count)
print("Thought token count:", response.usage_metadata.thoughts_token_count)
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: 4
# Output tokens: 46
# Thought token count: None
# Total tokens used: 50

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc"
client= genai.Client()

prompt = "Explain cloud computing in maximum 200 tokens."

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt ,
    config=types.GenerateContentConfig(
       temperature=0.4, #from 0 to 2
       top_p=0.7, #from 0 to 1
       thinking_config=types.ThinkingConfig(thinking_budget=0),max_output_tokens=250
        
))
print("Response:", response.text)
# Out:
# Response: Cloud computing delivers on-demand computing services—like servers, storage, databases, networking, software, analytics, and intelligence—over the internet ("the cloud"). Instead of owning and maintaining your own computing infrastructure, you can access these services from a cloud provider (e.g., AWS, Azure, Google Cloud) and pay only for what you use. It offers flexibility, scalability, and cost-efficiency.

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Explain cloud computing in maximum 200 tokens."

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt,
    config=types.GenerateContentConfig(
        safety_settings=[
            types.SafetySetting(
                category=types.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=types.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
            ),
           
        ]
    )
)
print("Response:", response.text)
# Out:
# Response: Cloud computing delivers on-demand computing services—including servers, storage, databases, networking, software, analytics, and intelligence—over the Internet ("the cloud").
#
# Instead of owning and maintaining physical data centers and servers, you can access these resources from a cloud provider (like AWS, Azure, Google Cloud) as needed. You only pay for the services you consume.
#
# It offers scalability (easily expand or shrink resources), flexibility, and cost-efficiency by eliminating the need for upfront hardware investments and ongoing maintenance. Think of it like renting computing power and storage rather than buying and managing it yourself.

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBoj3dUSCv68-YN1ur_06e0oPyUTjKXeMc"
client= genai.Client()

prompt = "Capital of india?"

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a helpful assistant that provides concise explanations."
    ),
)
print("Response:", response.text)
# Out:
# Response: New Delhi

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Capital of india?"

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a coding  assistant, only respond to coding related questions"
    ),
)
print("Response:", response.text)
# Out:
# Response: I am a coding assistant and can only respond to coding-related questions.

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Tell me about India history?"

response = client.models.generate_content_stream(
    model="gemini-2.5-flash", contents=prompt,
    #limit max token 200
    # config=types.GenerateContentConfig(
    #    max_output_tokens=500
    # ),
        
)
for chunk in response:
     print(chunk.text, end='', flush=True)
# Out:
# India has one of the oldest and most diverse histories in the world, spanning millennia. It's a land of ancient civilizations, empires, philosophical and religious movements, and profound cultural achievements.
#
# Here's a broad overview of Indian history, broken down into major periods:
#
# ---
#
# ### I. Ancient India (c. 3300 BCE – 550 CE)
#
# 1.  **Indus Valley Civilization (c. 3300-1900 BCE):**
#     *   One of the world's earliest urban civilizations, flourishing around the Indus River and its tributaries.
#     *   Major cities like Harappa and Mohenjo-Daro showcased advanced urban planning, drainage systems, and sophisticated craftsmanship.
#     *   Known for its distinctive pottery, seals, and enigmatic script (still undeciphered).
#     *   Its decline around 1900 BCE is attributed to various factors, including climate change, shifting river patterns, or invasions.
#
# 2.  **Vedic Period (c. 1500-500 BCE):**
#     *   Characterized by the Indo-Aryan migration/synthesis and the composition of the Vedas, sacred texts that form the foundation of Hinduism.
#     *   Society was organized into tribal units, gradually evolving into kingdoms.
#     *   The caste system (Varna system) began to take shape during this period.
#     *   Development of early philosophical ideas, rituals, and the Sanskrit language.
#
# 3.  **Mahajanapadas and the Rise of New Religions (c. 600-322 BCE):**
#     *   Emergence of 16 powerful kingdoms or "Mahajanapadas" across northern India, with Magadha eventually becoming the most dominant.
#     *   This era saw the birth of two major indigenous religions:
#         *   **Buddhism:** Founded by Siddhartha Gautama (the Buddha), emphasizing the Four Noble Truths and the Eightfold Path to achieve nirvana.
#         *   **Jainism:** Revitalized by Mahavira, advocating extreme non-violence (ahimsa) and asceticism.
#
# 4.  **Mauryan Empire (c. 322-185 BCE):**
#     *   Founded by Chandragupta Maurya, who unified much of the Indian subcontinent for the first time.
#     *   His grandson, **Ashoka the Great**, initially a fierce conqueror, converted to Buddhism after the Kalinga War and became a proponent of peace and dharma, spreading Buddhism far and wide through rock edicts and missionaries.
#     *   The empire had a highly centralized administration and advanced infrastructure.
#
# 5.  **Post-Mauryan Period and Regional Kingdoms (c. 185 BCE - 320 CE):**
#     *   After the Mauryan decline, India saw the rise of various regional powers, including the Shungas, Satavahanas (Deccan), Kushans (Northwest, known for Gandhara art), and several South Indian kingdoms like the Cheras, Cholas, and Pandyas.
#     *   Increased trade with the Roman Empire and Southeast Asia.
#
# 6.  **Gupta Empire (c. 320-550 CE):**
#     *   Often called the "Golden Age of India," the Guptas brought political stability and fostered immense achievements in science, mathematics, astronomy, arts, and literature.
#     *   Key innovations include the concept of zero, the decimal system, and the flourishing of Sanskrit literature (e.g., Kalidasa).
#     *   Hinduism saw a resurgence and the development of classical temple architecture.
#
# ---
#
# ### II. Medieval India (c. 550 CE – 1757 CE)
#
# 1.  **Post-Gupta Period & Early Medieval Kingdoms (c. 550-1200 CE):**
#     *   Political fragmentation after the Guptas.
#     *   Rise of numerous regional dynasties: Harshavardhana in the North, Pallavas, Chalukyas, Rashtrakutas, and the powerful Chola Empire in the South (known for naval power, temple architecture, and bronze sculptures).
#     *   Increased trade and cultural exchange with Southeast Asia.
#     *   The beginning of Islamic incursions into Sindh (712 CE).
#
# 2.  **Delhi Sultanate (1206-1526 CE):**
#     *   Established by Turkic and Afghan invaders, it marked the beginning of sustained Islamic rule over large parts of North India.
#     *   Various dynasties ruled, including the Mamluks (Slave Dynasty), Khaljis, Tughlaqs, Sayyids, and Lodis.
#     *   Significant cultural synthesis, new architectural styles (Indo-Islamic), and the emergence of Urdu language.
#     *   During this period, the powerful Hindu **Vijayanagara Empire** flourished in South India (1336-1646 CE), acting as a bulwark against northern expansion.
#
# 3.  **Mughal Empire (1526-1857 CE):**
#     *   Founded by Babur, a descendant of Timur and Genghis Khan.
#     *   Reached its zenith under emperors like **Akbar the Great** (known for his administrative reforms, religious tolerance, and cultural patronage), Jahangir, Shah Jahan (builder of the Taj Mahal), and Aurangzeb (who expanded the empire to its largest extent but faced rebellions due to his religious policies).
#     *   A period of immense artistic, architectural, and literary achievement, blending Persian, Islamic, and Indian traditions.
#     *   Decline began after Aurangzeb's death, facing challenges from the Marathas and other regional powers.
#
# ---
#
# ### III. Colonial India (c. 1757 – 1947 CE)
#
# 1.  **Arrival of European Powers (16th-18th Centuries):**
#     *   Portuguese, Dutch, French, and British traders arrived, primarily seeking spices and other goods.
#     *   The **British East India Company** gradually gained political and military dominance through treaties, wars, and exploiting the fragmentation of the Mughal Empire.
#     *   Key battles like the Battle of Plassey (1757) and Buxar (1764) established British supremacy.
#
# 2.  **Company Rule (1757-1858 CE):**
#     *   The British East India Company ruled vast territories, characterized by economic exploitation, drain of wealth, and suppression of local industries.
#     *   Introduction of new land revenue systems and administrative structures.
#
# 3.  **The First War of Independence (1857):**
#     *   A widespread rebellion against British rule, often called the "Sepoy Mutiny."
#     *   Though suppressed, it led to the dissolution of the East India Company.
#
# 4.  **The British Raj (1858-1947 CE):**
#     *   Direct rule by the British Crown.
#     *   Introduction of railways, postal services, telegraphs, and a modern education system (primarily to serve British administrative needs).
#     *   Consolidation of a centralized administration but also increased economic exploitation and famines.
#     *   **Rise of Indian Nationalism:** The late 19th and early 20th centuries saw the emergence of various nationalist movements and organizations, most notably the **Indian National Congress**.
#     *   **Mahatma Gandhi** became the pre-eminent leader, advocating non-violent civil disobedience (Satyagraha) and mass movements (Non-Cooperation, Civil Disobedience, Quit India).
#     *   Other important leaders included Jawaharlal Nehru, Sardar Vallabhbhai Patel, Subhas Chandra Bose, and Bhagat Singh.
#     *   The demand for a separate Muslim state by the **Muslim League** under Muhammad Ali Jinnah gained momentum.
#
# 5.  **Partition and Independence (1947):**
#     *   After World War II, Britain decided to grant India independence.
#     *   Due to irreconcilable differences between the Indian National Congress and the Muslim League, India was partitioned into two independent nations: **India** and **Pakistan** (which included East Pakistan, later Bangladesh).
#     *   This led to widespread communal violence, mass migrations, and immense human suffering.
#     *   India officially gained independence on **August 15, 1947**.
#
# ---
#
# ### IV. Post-Independence India (1947 CE - Present)
#
# 1.  **Early Years (1947-1960s):**
#     *   Jawaharlal Nehru became India's first Prime Minister, championing secularism, democracy, and a non-aligned foreign policy.
#     *   Integration of princely states, framing of the Constitution, and establishment of democratic institutions.
#     *   Focus on industrialization and economic planning.
#
# 2.  **Challenges and Growth (1970s-1990s):**
#     *   Wars with Pakistan and China, internal political turmoil (e.g., The Emergency 1975-77).
#     *   Green Revolution transformed agricultural output.
#     *   Assassinations of Indira Gandhi (1984) and Rajiv Gandhi (1991).
#     *   Economic liberalization began in 1991, opening up the Indian economy to global markets.
#
# 3.  **Modern India (2000s-Present):**
#     *   Emergence as a major global economic and political power.
#     *   Significant growth in information technology and services sectors.
#     *   Continues to grapple with issues like poverty, social inequality, communal harmony, and environmental concerns.
#     *   Maintains its status as the world's largest democracy, known for its vibrant pluralism and cultural diversity.
#
# ---
#
# This is a vast subject, and each period and event could fill volumes, but this overview provides the key milestones and themes in India's incredibly rich and continuous historical journey.
