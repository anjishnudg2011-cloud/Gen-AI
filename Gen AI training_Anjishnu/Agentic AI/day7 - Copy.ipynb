# %%
#%pip install google-genai google-auth

# %%
#pip install google-genai
#pip install google-auth
 
from google.genai import Client
from google.oauth2.service_account import Credentials
api_key_path = "wpuser22-1357f7e639c5.json"
 
credentials = Credentials.from_service_account_file(
    api_key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"]
)
 
PROJECT_ID =  "wpuser22"
REGION = "us-central1"
MODEL_NAME = "gemini-2.5-flash"
 
client = Client(
    vertexai=True,
    project=PROJECT_ID,
    location=REGION,
    credentials=credentials
)

# %%
#pip install google-genai
#pip install google-auth
#using gcloud executing program
from google.genai import Client
 
PROJECT_ID =  "wpuser22"
REGION = "us-central1"
MODEL_NAME = "gemini-2.5-flash"
 
client = Client(
    vertexai=True,
    project=PROJECT_ID,
    location=REGION,
)
 
response = client.models.generate_content(
    model=MODEL_NAME,
    contents="What is the color of Apple"
)
 
print("Model Response:\n", response.text)
# Out:
# Model Response:
#  That depends on whether you're asking about:
#
# 1.  **The fruit (an apple):** Apples come in a wide variety of colors, most commonly:
#     *   **Red** (e.g., Red Delicious, Gala, Fuji)
#     *   **Green** (e.g., Granny Smith)
#     *   **Yellow** (e.g., Golden Delicious)
#     *   They can also be pink, or a mix of these colors.
#
# 2.  **The company (Apple Inc.):**
#     *   **Their iconic logo** (the bitten apple) is typically depicted in a **monochrome** fashion – often **silver, white, black, or shades of grey**, depending on the background or product it's on. It's not usually a specific color like red or blue.
#     *   **Their products** often come in neutral colors like **silver, space gray, midnight, starlight, white, or black**. However, they also offer products in a range of vibrant colors (e.g., some iPhone models, iMacs, Apple Watch bands).
#
# So, there isn't one single "color of Apple" without specifying if you mean the fruit or the tech company!

# %%
import os
from google import genai

os.environ["GOOGLE_API_KEY"] = "AIzaSyDV4e0YGBrtuWR8kJrm1SduK47hQ3OgRO4"
client = genai.Client()
'''
client= genai.Client(
    api_key="AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM",
)
'''
response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI analyzes data to find patterns and make predictions.

# %%
print("total output tokens:", response.usage_metadata.total_token_count)
# Out:
# total output tokens: 234

# %%
from google import genai
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDV4e0YGBrtuWR8kJrm1SduK47hQ3OgRO4"
client= genai.Client()

prompt = "Explain machine learning"
input_tokens_count=client.models.count_tokens(
    model="gemini-3-flash-preview",
    contents=prompt 
)
print("Input tokens:", input_tokens_count)

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt 
)
print("Response:", response.text)   
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) total_tokens=4 cached_content_token_count=None
# Response: At its simplest, **Machine Learning (ML)** is a subfield of Artificial Intelligence (AI) that focuses on building systems that learn from data.
#
# Instead of a human programmer writing specific instructions for every task, the computer uses **algorithms** (mathematical patterns) to discover insights and make decisions based on the information it is given.
#
# Here is a breakdown of how it works, the different types, and how we use it every day.
#
# ---
#
# ### 1. Traditional Programming vs. Machine Learning
# To understand ML, it helps to compare it to how computers usually work:
#
# *   **Traditional Programming:** A human writes a set of rules (**If** this happens, **then** do that). The computer follows those rules blindly to produce an output.
# ...

# %%
print(dir(response.usage_metadata))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydanti
# ...

# %%
print("Input tokens:", response.usage_metadata.prompt_token_count)
print("Output tokens:", response.usage_metadata.candidates_token_count)
print("Thought token count:", response.usage_metadata.thoughts_token_count)
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: 4
# Output tokens: 938
# Thought token count: 522
# Total tokens used: 1464

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDV4e0YGBrtuWR8kJrm1SduK47hQ3OgRO4"
client= genai.Client()

prompt = "Explain cloud computing"

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt ,
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0))
)
print("Response:", response.text)
# Out:
# Response: At its simplest, **cloud computing is the delivery of computing services over the internet.**
#
# Instead of keeping data files on your hard drive or running programs from a physical server in your office, you access those resources via the internet from a provider like Amazon (AWS), Microsoft (Azure), or Google (Google Cloud).
#
# Here is a breakdown of how it works, why it’s used, and the different ways it is delivered.
#
# ---
#
# ### 1. The Core Concept: "The Cloud" is just someone else's computer
# When you use the cloud, you are connecting to a massive **data center** filled with thousands of servers. These data centers are owned and maintained by "Cloud Providers." They handle the hardware, the electricity, the cooling, and the security, while you simply rent the capacity you need.
#
# ### 2. The Main Benefits
# Before the cloud, businesses had to buy expensive hardware and hire experts to maintain it. The cloud changed this with four key advantages:
# ...

# %%
print("Input tokens:", response.usage_metadata.prompt_token_count)
print("Output tokens:", response.usage_metadata.candidates_token_count)
print("Thought token count:", response.usage_metadata.thoughts_token_count)
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: 4
# Output tokens: 718
# Thought token count: None
# Total tokens used: 722

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDV4e0YGBrtuWR8kJrm1SduK47hQ3OgRO4"
client= genai.Client()

prompt = "Explain cloud computing"

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt ,
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0),max_output_tokens=50 ),
        
)
print("Response:", response.text)
# Out:
# Response: At its simplest, **cloud computing is the delivery of computing services over the internet.**
#
# Instead of keeping data on your own hard drive or managing your own physical servers in a closet, you "rent" those resources from companies like

# %%
print("Input tokens:", response.usage_metadata.prompt_token_count)
print("Output tokens:", response.usage_metadata.candidates_token_count)
print("Thought token count:", response.usage_metadata.thoughts_token_count)
print("Total tokens used:", response.usage_metadata.total_token_count)
# Out:
# Input tokens: 4
# Output tokens: 46
# Thought token count: None
# Total tokens used: 50

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDV4e0YGBrtuWR8kJrm1SduK47hQ3OgRO4"
client= genai.Client()

prompt = "Explain cloud computing in maximum 200 tokens."

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt ,
    config=types.GenerateContentConfig(
       temperature=0.4, #from 0 to 2
       top_p=0.7, #from 0 to 1
       thinking_config=types.ThinkingConfig(thinking_budget=0),max_output_tokens=250
        
))
print("Response:", response.text)
# Out:
# Response: Cloud computing is the on-demand delivery of computing services—including servers, storage, databases, networking, and software—over the internet ("the cloud").
#
# Instead of owning and maintaining physical data centers and hard drives, you rent access to these resources from providers like Amazon (AWS), Microsoft (Azure), or Google (GCP).
#
# **Key Characteristics:**
# *   **On-Demand:** You access resources instantly whenever you need them.
# *   **Scalability:** You can easily increase or decrease capacity based on traffic.
# *   **Pay-as-you-go:** You only pay for the resources you actually use, reducing upfront capital costs.
#
# **Common Models:**
# 1.  **SaaS (Software as a Service):** Using apps via a browser (e.g., Gmail, Netflix).
# 2.  **PaaS (Platform as a Service):** Tools for developers to build and host apps without managing infrastructure.
# 3.  **IaaS (Infrastructure as a Service):** Renting raw virtual servers and storage.
#
# ...

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Explain cloud computing in maximum 200 tokens."

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt,
    config=types.GenerateContentConfig(
        safety_settings=[
            types.SafetySetting(
                category=types.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=types.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
            ),
           
        ]
    )
)
print("Response:", response.text)
# Out:
# Response: Cloud computing is the on-demand delivery of computing power, database storage, applications, and other IT resources via the internet. Instead of managing physical servers or local hard drives, you access these services from providers like AWS, Microsoft Azure, or Google Cloud.
#
# **Key Benefits:**
# *   **Cost:** Pay only for what you use (pay-as-you-go), eliminating high upfront hardware costs.
# *   **Scalability:** Instantly increase or decrease resources based on demand.
# *   **Accessibility:** Access data and tools from any location with an internet connection.
#
# **Service Models:**
# 1.  **IaaS (Infrastructure):** Renting raw hardware like virtual servers and storage.
# 2.  **PaaS (Platform):** Providing tools and frameworks for developers to build and host applications.
# 3.  **SaaS (Software):** Ready-to-use applications delivered through a web browser (e.g., Slack, Gmail, or Microsoft 365).
#
# ...

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Capital of india?"

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a helpful assistant that provides concise explanations."
    ),
)
print("Response:", response.text)
# Out:
# Response: The capital of India is **New Delhi**.

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Capital of india?"

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a coding  assistant, only respond to coding related questions"
    ),
)
print("Response:", response.text)
# Out:
# Response: I am a coding assistant and can only respond to coding-related questions. If you have a programming query, feel free to ask!

# %%
from google import genai
from google.genai import types
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAwc8faOru3cA45F19Q3G6kVYjSoQCFmSM"
client= genai.Client()

prompt = "Tell me about India history?"

response = client.models.generate_content_stream(
    model="gemini-3-flash-preview", contents=prompt,
    #limit max token 200
    # config=types.GenerateContentConfig(
    #    max_output_tokens=500
    # ),
        
)
for chunk in response:
     print(chunk.text, end='', flush=True)
# Out:
# Indian history is one of the world's oldest and most complex narratives, spanning over 5,000 years. To understand it, it is best to divide it into four major eras: **Ancient, Medieval, Colonial, and Modern.**
#
# ---
#
# ### 1. Ancient India (Prehistory – 800 CE)
# *   **Indus Valley Civilization (c. 3300–1300 BCE):** One of the world’s earliest urban civilizations (Harappa and Mohenjo-daro). They were known for advanced town planning, drainage systems, and trade.
# *   **Vedic Period (c. 1500–500 BCE):** The Indo-Aryans arrived, and the Vedas (sacred Hindu texts) were composed. This period saw the foundations of Hinduism and the caste system.
# *   **Rise of Buddhism and Jainism (6th Century BCE):** Great thinkers like Gautama Buddha and Mahavira challenged existing rituals, preaching non-violence and enlightenment.
# ...
