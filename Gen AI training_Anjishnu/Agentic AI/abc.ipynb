# %%
# %pip install google-cloud-aiplatform

from google.cloud import aiplatform
from vertexai.language_models import TextEmbeddingModel
from google.cloud.aiplatform_v1.types import index as index_types
import uuid
# Out:
# Requirement already satisfied: google-cloud-aiplatform in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.143.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.30.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (2.49.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (1.27.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (26.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.10.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (3.10.1)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (3.40.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.59.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (1.68.0)
# Requirement already satisfied: pydantic<3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (2.12.5)
# Requirement already satisfied: typing_extensions in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (4.15.0)
# Requirement already satisfied: docstring_parser<1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-aiplatform) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.73.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.78.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (46.0.6)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-storage<4.0.0,>=2.10.0->google-cloud-aiplatform) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (4.12.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (3.11)
# Requirement already satisfied: certifi in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3->google-cloud-aiplatform) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install google-cloud-aiplatform

from google.cloud import aiplatform
from vertexai.language_models import TextEmbeddingModel
from google.cloud.aiplatform_v1.types import index as index_types
import uuid

#  1. Init Vertex AI
PROJECT_ID = "gen-lang-client-0384449393"
LOCATION = "us-central1"
aiplatform.init(project=PROJECT_ID, location=LOCATION)

#  2. Load text file from GCS
from google.cloud import storage

BUCKET_NAME = "fictbank_01"
BLOB_NAME = "wibank_terms.txt"

storage_client = storage.Client()
bucket = storage_client.bucket(BUCKET_NAME)
blob = bucket.blob(BLOB_NAME)
text_data = blob.download_as_text()

# %%
# Split into small chunks (for embeddings)
documents = [line.strip() for line in text_data.split("\n") if line.strip()]

#  3. Create embeddings
embedding_model = TextEmbeddingModel.from_pretrained("text-embedding-004")

embeddings = [
    embedding_model.get_embeddings([doc])[0].values for doc in documents
]

print(f"Created {len(embeddings)} embeddings of dimension {len(embeddings[0])}")
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     437 """See grpc.Future.result."""
# --> 438 raise self
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:1173, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 state, call = self._blocking(
#    1171     request, timeout, metadata, credentials, wait_for_ready, compression
#    1172 )
# -> 1173 return _end_unary_response_blocking(state, call, True, None)
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:990, in _end_unary_response_blocking(state, call, with_call, deadline)
#     989     return state.response
# --> 990 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/generative-ai/quotas-genai."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:216.239.38.223:443 {grpc_message:"Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/generative-ai/quotas-genai.", grpc_status:8}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[6], line 8
#       4 #  3. Create embeddings
#       5 embedding_model = TextEmbeddingModel.from_pretrained("text-embedding-004")
#       7 embeddings = [
# ----> 8     embedding_model.get_embeddings([doc])[0].values for doc in documents
#       9 ]
#      11 print(f"Created {len(embeddings)} embeddings of dimension {len(embeddings[0])}")
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\vertexai\language_models\_language_models.py:2196, in _TextEmbeddingModel.get_embeddings(self, texts, auto_truncate, output_dimensionality)
#    2179 """Calculates embeddings for the given texts.
#    2180
#    2181 Args:
#    (...)   2188     A list of `TextEmbedding` objects.
#    2189 """
#    2190 prediction_request = self._prepare_text_embedding_request(
#    2191     texts=texts,
#    2192     auto_truncate=auto_truncate,
#    2193     output_dimensionality=output_dimensionality,
#    2194 )
# -> 2196 prediction_response = self._endpoint.predict(
#    2197     instances=prediction_request.instances,
#    2198     parameters=prediction_request.parameters,
#    2199 )
#    2201 return [
#    2202     TextEmbedding._parse_text_embedding_response(
#    2203         prediction_response, i_prediction
#    2204     )
#    2205     for i_prediction, _ in enumerate(prediction_response.predictions)
#    2206 ]
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\aiplatform\models.py:2630, in Endpoint.predict(self, instances, parameters, timeout, use_raw_predict, use_dedicated_endpoint)
#    2615     return Prediction(
#    2616         predictions=json_response["predictions"],
#    2617         metadata=json_response.get("metadata"),
#    (...)   2626         ),
#    2627     )
#    2629 if not self.dedicated_endpoint_enabled:
# -> 2630     prediction_response = self._prediction_client.predict(
#    2631         endpoint=self._gca_resource.name,
#    2632         instances=instances,
#    2633         parameters=parameters,
#    2634         timeout=timeout,
#    2635     )
#    2636     if prediction_response._pb.metadata:
#    2637         metadata = json_format.MessageToDict(prediction_response._pb.metadata)
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\aiplatform_v1\services\prediction_service\client.py:1014, in PredictionServiceClient.predict(self, request, endpoint, instances, parameters, retry, timeout, metadata)
#    1011 self._validate_universe_domain()
#    1013 # Send the request.
# -> 1014 response = rpc(
#    1015     request,
#    1016     retry=retry,
#    1017     timeout=timeout,
#    1018     metadata=metadata,
#    1019 )
#    1021 # Done; return the response.
#    1022 return response
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\gapic_v1\method.py:128, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     125 if self._compression is not None:
#     126     kwargs["compression"] = compression
# --> 128 return wrapped_func(*args, **kwargs)
#
# File c:\Users\Roni\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\grpc_helpers.py:57, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
# ---> 57     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/generative-ai/quotas-genai.
